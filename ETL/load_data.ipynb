# %%
import numpy as np
import pandas as pd

# %%
import json

# %%
from tools import *

# %%
from load_data import *

# %% [markdown]
# # Load data

# %%
ori = ['編號','東(正)','東(副)','東(冷)','東方共',
       '蘋(正)','蘋(副)','蘋(冷)','蘋果共',
       '專(正)','專(副)','專(冷)','專業共',
       '正','副','冷','總數','W.H. FixOdd','S.B.      FixOdd']

new = ['horse_num','oriental_1','oriental_2','oriental_3','oriental_sum',
       'apple_1','apple_2','apple_3','apple_sum',
       'pro_1','pro_2','pro_3','pro_sum',
       'total_1','total_2','total_3','total_sum','w_h_odd','s_b_odd']

mapper = {i:j for i,j in zip(ori, new)}

# %% [markdown]
# # 5/1

# %% [markdown]
# # All data

# %%
all_dirs = [i for i in os.listdir('../../extra_size_files/data/') if i != '.DS_Store']

# %%
all_data = pd.concat([flow_from_dir('../../extra_size_files/data/'+i, '.xls', 'Race', \
                                    mapper, verbose=True) for i in all_dirs]).reset_index(drop=True)
# Out:
# File 1
# Loading file: ../../extra_size_files/data/4_29_2020/M2019-10-30D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Status: Completed
#
# File 2
# Loading file: ../../extra_size_files/data/4_29_2020/M2019-10-27D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Loaded: Race(11)
# Status: Completed
#
# File 3
# Loading file: ../../extra_size_files/data/4_29_2020/M2019-09-11D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Status: Completed
#
# File 4
# Loading file: ../../extra_size_files/data/4_29_2020/M2019-10-16D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# ...

# %% [markdown]
# # All result

# %%
all_dirs_result = list()
for i in os.listdir('./result/'):
    with open('./result/'+i) as f:
        all_dirs_result.append(json.load(f))

# %%
all_results = combine_dicts(all_dirs_result)

# %% [markdown]
# # Map data result

# %%
mapped_data = map_result_to_data(all_data, all_results)
# Out:
# Race day 2019_09_18 has no result
