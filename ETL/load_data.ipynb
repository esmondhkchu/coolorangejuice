# %%
import numpy as np
import pandas as pd

# %%
from load_data import *

# %% [markdown]
# # Load data

# %%
ori = ['編號','東(正)','東(副)','東(冷)','東方共',
       '蘋(正)','蘋(副)','蘋(冷)','蘋果共',
       '專(正)','專(副)','專(冷)','專業共',
       '正','副','冷','總數','W.H. FixOdd','S.B.      FixOdd']

new = ['horse_num','oriental_1','oriental_2','oriental_3','oriental_sum',
       'apple_1','apple_2','apple_3','apple_sum',
       'pro_1','pro_2','pro_3','pro_sum',
       'total_1','total_2','total_3','total_sum','w_h_odd','s_b_odd']

mapper = {i:j for i,j in zip(ori, new)}

# %%
data_4_27 = flow_from_dir('../../extra_size_files/data/4_27_2020/', '.xls', 'Race', mapper)
# Out:
# File 1
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-10-30D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Status: Completed
#
# File 2
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-10-27D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Loaded: Race(11)
# Status: Completed
#
# File 3
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-09-11D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Status: Completed
#
# File 4
# Loading file: ../../extra_size_files/data/4_27_2020/M2020-04-26D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Status: Completed
#
# File 5
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-10-16D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Loaded: Race(11)
# Status: Completed
#
# File 6
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-10-20D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Status: Completed
#
# File 7
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-09-01D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Loaded: Race(11)
# Status: Completed
#
# File 8
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-09-21D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Loaded: Race(11)
# Status: Completed
#
# File 9
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-10-01D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Status: Completed
#
# File 10
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-09-18D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Status: Completed
#
# File 11
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-09-15D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Loaded: Race(11)
# Status: Completed
#
# File 12
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-10-23D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Status: Completed
#
# File 13
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-09-08D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Loaded: Race(11)
# Status: Completed
#
# File 14
# Loading file: ../../extra_size_files/data/4_27_2020/M2019-09-25D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Status: Completed
#
# Loaded 14 files

# %%
result_4_27 = extract_missing_result(data_4_27, '../../../geckodriver')
# Out:
# Loaded Result for: 2019_10_30_1
# Loaded Result for: 2019_10_30_2
# Loaded Result for: 2019_10_30_3
# Loaded Result for: 2019_10_30_4
# Loaded Result for: 2019_10_30_5
# Loaded Result for: 2019_10_30_6
# Loaded Result for: 2019_10_30_7
# Loaded Result for: 2019_10_30_8
# Failed to Load Result for: 2019_10_30_9
# Loaded Result for: 2019_10_27_1
# Loaded Result for: 2019_10_27_2
# Loaded Result for: 2019_10_27_3
# Loaded Result for: 2019_10_27_4
# Loaded Result for: 2019_10_27_5
# Loaded Result for: 2019_10_27_6
# Loaded Result for: 2019_10_27_7
# Loaded Result for: 2019_10_27_8
# Loaded Result for: 2019_10_27_9
# Failed to Load Result for: 2019_10_27_10
# Failed to Load Result for: 2019_10_27_11
# Loaded Result for: 2019_09_11_1
# Loaded Result for: 2019_09_11_2
# Loaded Result for: 2019_09_11_3
# Loaded Result for: 2019_09_11_4
# Loaded Result for: 2019_09_11_5
# Loaded Result for: 2019_09_11_6
# Loaded Result for: 2019_09_11_7
# Loaded Result for: 2019_09_11_8
# Failed to Load Result for: 2019_09_11_9
# Loaded Result for: 2019_10_16_1
# Loaded Result for: 2019_10_16_2
# Loaded Result for: 2019_10_16_3
# Loaded Result for: 2019_10_16_4
# Loaded Result for: 2019_10_16_5
# Loaded Result for: 2019_10_16_6
# Loaded Result for: 2019_10_16_7
# Loaded Result for: 2019_10_16_8
# Failed to Load Result for: 2019_10_16_9
# Failed to Load Result for: 2019_10_16_10
# Failed to Load Result for: 2019_10_16_11
# Loaded Result for: 2019_10_20_1
# Loaded Result for: 2019_10_20_2
# Loaded Result for: 2019_10_20_3
# Loaded Result for: 2019_10_20_4
# Loaded Result for: 2019_10_20_5
# Loaded Result for: 2019_10_20_6
# Loaded Result for: 2019_10_20_7
# Loaded Result for: 2019_10_20_8
# Loaded Result for: 2019_10_20_9
# Loaded Result for: 2019_10_20_10
# Loaded Result for: 2019_09_01_1
# Loaded Result for: 2019_09_01_2
# Loaded Result for: 2019_09_01_3
# Loaded Result for: 2019_09_01_4
# Loaded Result for: 2019_09_01_5
# Loaded Result for: 2019_09_01_6
# Loaded Result for: 2019_09_01_7
# Loaded Result for: 2019_09_01_8
# Loaded Result for: 2019_09_01_9
# Loaded Result for: 2019_09_01_10
# Failed to load expected page source
# Failed to Load Result for: 2019_09_01_11
# Loaded Result for: 2019_09_21_1
# Loaded Result for: 2019_09_21_2
# Loaded Result for: 2019_09_21_3
# Loaded Result for: 2019_09_21_4
# Loaded Result for: 2019_09_21_5
# Loaded Result for: 2019_09_21_6
# Loaded Result for: 2019_09_21_7
# Loaded Result for: 2019_09_21_8
# Loaded Result for: 2019_09_21_9
# Loaded Result for: 2019_09_21_10
# Failed to Load Result for: 2019_09_21_11
# Loaded Result for: 2019_10_01_1
# Loaded Result for: 2019_10_01_2
# Loaded Result for: 2019_10_01_3
# Loaded Result for: 2019_10_01_4
# Loaded Result for: 2019_10_01_5
# Loaded Result for: 2019_10_01_6
# Loaded Result for: 2019_10_01_7
# Loaded Result for: 2019_10_01_8
# Loaded Result for: 2019_10_01_9
# Loaded Result for: 2019_10_01_10
# Loaded Result for: 2019_09_18_1
# Loaded Result for: 2019_09_18_2
# Loaded Result for: 2019_09_18_3
# Loaded Result for: 2019_09_18_4
# Loaded Result for: 2019_09_18_5
# Loaded Result for: 2019_09_18_6
# Loaded Result for: 2019_09_18_7
# Loaded Result for: 2019_09_18_8
# Loaded Result for: 2019_09_15_1
# Loaded Result for: 2019_09_15_2
# Loaded Result for: 2019_09_15_3
# Loaded Result for: 2019_09_15_4
# Loaded Result for: 2019_09_15_5
# Loaded Result for: 2019_09_15_6
# Loaded Result for: 2019_09_15_7
# Loaded Result for: 2019_09_15_8
# Loaded Result for: 2019_09_15_9
# Loaded Result for: 2019_09_15_10
# Failed to Load Result for: 2019_09_15_11
# Loaded Result for: 2019_10_23_1
# Loaded Result for: 2019_10_23_2
# Loaded Result for: 2019_10_23_3
# Loaded Result for: 2019_10_23_4
# Loaded Result for: 2019_10_23_5
# Loaded Result for: 2019_10_23_6
# Loaded Result for: 2019_10_23_7
# Loaded Result for: 2019_10_23_8
# Loaded Result for: 2019_10_23_9
# Loaded Result for: 2019_09_08_1
# Loaded Result for: 2019_09_08_2
# Loaded Result for: 2019_09_08_3
# Loaded Result for: 2019_09_08_4
# Loaded Result for: 2019_09_08_5
# Loaded Result for: 2019_09_08_6
# Loaded Result for: 2019_09_08_7
# Loaded Result for: 2019_09_08_8
# Loaded Result for: 2019_09_08_9
# Loaded Result for: 2019_09_08_10
# Failed to Load Result for: 2019_09_08_11
# Loaded Result for: 2019_09_25_1
# Loaded Result for: 2019_09_25_2
# Loaded Result for: 2019_09_25_3
# Loaded Result for: 2019_09_25_4
# Loaded Result for: 2019_09_25_5
# Loaded Result for: 2019_09_25_6
# Loaded Result for: 2019_09_25_7
# Loaded Result for: 2019_09_25_8
# Loaded Result for: 2019_09_25_9
# Retrying: 2019_10_30_9
# Failed to Load Result for: 2019_10_30_9
# Retrying: 2019_10_27_10
# Failed to Load Result for: 2019_10_27_10
# Retrying: 2019_10_27_11
# Failed to Load Result for: 2019_10_27_11
# Retrying: 2019_09_11_9
# Failed to Load Result for: 2019_09_11_9
# Retrying: 2019_10_16_9
# Failed to Load Result for: 2019_10_16_9
# Retrying: 2019_10_16_10
# Failed to Load Result for: 2019_10_16_10
# Retrying: 2019_10_16_11
# Failed to Load Result for: 2019_10_16_11
# Retrying: 2019_09_01_11
# Failed to Load Result for: 2019_09_01_11
# Retrying: 2019_09_21_11
# Failed to Load Result for: 2019_09_21_11
# Retrying: 2019_09_15_11
# Failed to Load Result for: 2019_09_15_11
# Retrying: 2019_09_08_11
# Failed to Load Result for: 2019_09_08_11
