# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # Load data

# %%
from load_data import *

# %%
ori = ['編號','東(正)','東(副)','東(冷)','東方共',
       '蘋(正)','蘋(副)','蘋(冷)','蘋果共',
       '專(正)','專(副)','專(冷)','專業共',
       '正','副','冷','總數','W.H. FixOdd','S.B.      FixOdd']

# %%
new = ['horse_num','oriental_1','oriental_2','oriental_3','oriental_sum',
       'apple_1','apple_2','apple_3','apple_sum',
       'pro_1','pro_2','pro_3','pro_sum',
       'total_1','total_2','total_3','total_sum','w_h_odd','s_b_odd']

# %%
mapper = {i:j for i,j in zip(ori, new)}

# %%
all_data = flow_from_dir('./data', '.xls', 'Race', mapper)
# Out:
# File 1
# Loading file: ./data/M2019-11-27D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Status: Completed
#
# File 2
# Loading file: ./data/M2019-12-21D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Status: Completed
#
# File 3
# Loading file: ./data/M2020-01-08D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Status: Completed
#
# File 4
# Loading file: ./data/M2020-02-02D.xls
# Loaded: Race(1)
# Loaded: Race(2)
# Loaded: Race(3)
# Loaded: Race(4)
# Loaded: Race(5)
# Loaded: Race(6)
# Loaded: Race(7)
# Loaded: Race(8)
# Loaded: Race(9)
# Loaded: Race(10)
# Status: Completed
#
# File 5
# ...

# %%
all_data = all_data.sort_values(by=['file_name','sheet_name']).reset_index(drop=True)

# %%
# all_data.to_csv('data.csv', index=False)

# %% [markdown]
# Scrape Jockey Club

# %%
# in_result = {'_'.join(format_to_date(j['file_name']))+'_'+format_to_race(j['sheet_name']):eval(j['result']) for i,j in yo.iterrows()}

# %%
ori = ['編號','東(正)','東(副)','東(冷)','東方共',
       '蘋(正)','蘋(副)','蘋(冷)','蘋果共',
       '專(正)','專(副)','專(冷)','專業共',
       '正','副','冷','總數','W.H. FixOdd','S.B.      FixOdd']

new = ['horse_num','oriental_1','oriental_2','oriental_3','oriental_sum',
       'apple_1','apple_2','apple_3','apple_sum',
       'pro_1','pro_2','pro_3','pro_sum',
       'total_1','total_2','total_3','total_sum','w_h_odd','s_b_odd']

mapper = {i:j for i,j in zip(ori, new)}

# %%
from load_data import *

# %%
test_excel = load_whole_excel('../data_4_27/M2019-10-16D.xls', 'Race', mapper, verbose=False)

# %%
result_info = extract_missing_result(test_excel.head(12), '../../geckodriver')
# Out:
# Failed to Load Result for: 2019_10_16_1
# Retrying: 2019_10_16_1
# Loaded Result for: 2019_10_16_1
